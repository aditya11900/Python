# %%
import matplotlib.pyplot as plt

# Sample data
x = ['A', 'B', 'C', 'D', 'E']
y = [10, 24, 36, 40, 15]

# Create bar graph
plt.bar(x, y)

# Add labels and title
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Bar Graph')

# Show graph
plt.show()
